# %% [markdown]
# # 🔍Correlation Insights: Key Factors in Luxury Fashion Resale Data
#
# #### Overview:
# The Vestiaire Collective dataset, consisting of approximately 900,000 rows and 36 columns, offers a comprehensive view of the pre-owned luxury fashion market. The dataset includes information on product listings, sellers, pricing, and more, making it suitable for various analyses, including trend analysis, geographical analysis, and item price prediction.
#
# #### 1. Data Cleaning and Preprocessing:
# Before diving into the analysis, data cleaning and preprocessing were essential. This involved handling missing values, converting certain columns to categorical types, and performing feature engineering to enhance insights and model performance.
#
# #### 2. Exploratory Data Analysis (EDA):
# EDA helped in understanding the distribution and relationships within the data. Key metrics and trends were visualized to gain deeper insights into the dataset.
#
# #### 3. Geographical Analysis:
# The geographical analysis focused on identifying the most active regions for both buyers and sellers on Vestiaire Collective. This analysis aimed to uncover trends in user demographics and regional activity in the second-hand luxury fashion market.
#
# #### 4. Trend Analysis:
# Trend analysis involved investigating the current trends in second-hand luxury fashion. This included analyzing popular brands, product types, and pricing patterns to understand the market dynamics.
#
# #### 5. Price Prediction:
# To predict the prices of listed items, machine learning algorithms were utilized. The features available in the dataset were used to build models that can accurately predict item prices based on various attributes.
#
# ### Data Visualizations:
# Seven key visualizations were created using black color shades to enhance clarity and aesthetic consistency:
#
# #### 1. Distribution of Product Prices:
# A histogram with a kernel density estimate (KDE) was used to visualize the distribution of product prices. This helped in understanding the pricing spread and identifying common price ranges.
#
# #### 2. Top Brands by Number of Listings:
# A bar plot highlighted the top 10 brands with the most listings on Vestiaire Collective. This visualization showcased the dominance of certain brands in the second-hand luxury market.
#
# #### 3. Distribution of Product Conditions:
# A count plot depicted the distribution of product conditions, showing the frequency of items in various states (e.g., new, like new, good condition).
#
# #### 4. Geographical Distribution of Sellers:
# Another bar plot illustrated the top 10 countries by the number of sellers, providing insights into the global reach and regional concentration of sellers on the platform.
#
# #### 5. Product Categories by Gender Target:
# A count plot segmented by gender target showed the distribution of product categories, highlighting popular categories for different gender targets.
#
# #### 6. Trend of Sold vs. Available Products:
# A count plot compared the number of sold versus available products, helping to understand the market's supply-demand dynamics.
#
# #### 7. Correlation Heatmap of Numerical Features:
# A heatmap displayed the correlations between numerical features in the dataset. This helped in identifying relationships between variables, which is crucial for feature selection and understanding underlying patterns.
#
# ### Conclusion:
# The analysis of the Vestiaire Collective dataset provided valuable insights into the second-hand luxury fashion market. By leveraging various data visualizations and machine learning techniques, we gained a deeper understanding of market trends, geographical activity, and pricing dynamics. This comprehensive approach can aid in strategic decision-making for businesses and individuals involved in the pre-owned luxury fashion market.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Load the dataset
df = pd.read_csv("/kaggle/input/vestiaire-fashion-dataset/vestiaire.csv")

# Convert appropriate columns to categorical
df['product_gender_target'] = df['product_gender_target'].astype('category')
df['product_condition'] = df['product_condition'].astype('category')
df['seller_country'] = df['seller_country'].astype('category')

# Set a consistent style and color palette for plots
sns.set(style="whitegrid")
black_palette = ["#000000", "#333333", "#666666", "#999999"]

# %%
# 1. Distribution of Product Prices
plt.figure(figsize=(10, 6))
sns.histplot(df['price_usd'], bins=50, kde=True, color=black_palette[0])
plt.title('Distribution of Product Prices', fontsize=16)
plt.xlabel('Price in USD')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Top Brands by Number of Listings
top_brands = df['brand_name'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_brands.values, y=top_brands.index, palette=black_palette)
plt.title('Top Brands by Number of Listings', fontsize=16)
plt.xlabel('Number of Listings')
plt.ylabel('Brand Name')
plt.show()

# %%
# 3. Distribution of Product Conditions
plt.figure(figsize=(10, 6))
sns.countplot(y='product_condition', data=df, palette=black_palette)
plt.title('Distribution of Product Conditions', fontsize=16)
plt.xlabel('Frequency')
plt.ylabel('Product Condition')
plt.show()

# %%
# 4. Geographical Distribution of Sellers
top_countries = df['seller_country'].value_counts().head(10)
plt.figure(figsize=(10, 25))
sns.barplot(x=top_countries.values, y=top_countries.index, palette=black_palette)
plt.title('Top Countries by Number of Sellers', fontsize=16)
plt.xlabel('Number of Sellers')
plt.ylabel('Country')
plt.show()

# %%
# 5. Product Categories by Gender Target
plt.figure(figsize=(10, 6))
sns.countplot(y='product_category', hue='product_gender_target', data=df, palette=black_palette)
plt.title('Product Categories by Gender Target', fontsize=16)
plt.xlabel('Frequency')
plt.ylabel('Product Category')
plt.legend(title='Gender Target')
plt.show()

# %%
# 6. Trend of Sold vs. Available Products
plt.figure(figsize=(10, 6))
sns.countplot(x='sold', data=df, palette=black_palette)
plt.title('Sold vs. Available Products', fontsize=16)
plt.xlabel('Sold')
plt.ylabel('Frequency')
plt.show()

# %%
# Select only the numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
corr_matrix = df[numeric_cols].corr()

# 7. Correlation Heatmap of Numerical Features
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='Greys', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features', fontsize=16)
plt.show()
